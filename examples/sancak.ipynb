# %% [markdown]
# <div align="center">
#   <a href="https://ultralytics.com/yolo" target="_blank">
#     <img width="1024" src="https://raw.githubusercontent.com/ultralytics/assets/main/yolov8/banner-yolov8.png">
#   </a>
#
#   [中文](https://docs.ultralytics.com/zh/) | [한국어](https://docs.ultralytics.com/ko/) | [日本語](https://docs.ultralytics.com/ja/) | [Русский](https://docs.ultralytics.com/ru/) | [Deutsch](https://docs.ultralytics.com/de/) | [Français](https://docs.ultralytics.com/fr/) | [Español](https://docs.ultralytics.com/es/) | [Português](https://docs.ultralytics.com/pt/) | [Türkçe](https://docs.ultralytics.com/tr/) | [Tiếng Việt](https://docs.ultralytics.com/vi/) | [العربية](https://docs.ultralytics.com/ar/)
#
#   <a href="https://github.com/ultralytics/ultralytics/actions/workflows/ci.yml"><img src="https://github.com/ultralytics/ultralytics/actions/workflows/ci.yml/badge.svg" alt="Ultralytics CI"></a>
#   <a href="https://clickpy.clickhouse.com/dashboard/ultralytics"><img src="https://static.pepy.tech/badge/ultralytics" alt="Ultralytics Downloads"></a>
#   <a href="https://discord.com/invite/ultralytics"><img alt="Ultralytics Discord" src="https://img.shields.io/discord/1089800235347353640?logo=discord&logoColor=white&label=Discord&color=blue"></a>
#   <a href="https://community.ultralytics.com/"><img alt="Ultralytics Forums" src="https://img.shields.io/discourse/users?server=https%3A%2F%2Fcommunity.ultralytics.com&logo=discourse&label=Forums&color=blue"></a>
#   <a href="https://www.reddit.com/r/ultralytics/"><img alt="Ultralytics Reddit" src="https://img.shields.io/reddit/subreddit-subscribers/ultralytics?style=flat&logo=reddit&logoColor=white&label=Reddit&color=blue"></a>
#   <br>
#   <a href="https://console.paperspace.com/github/ultralytics/ultralytics/blob/main/examples/tutorial.ipynb"><img src="https://assets.paperspace.io/img/gradient-badge.svg" alt="Run Ultralytics on Gradient"></a>
#   <a href="https://colab.research.google.com/github/ultralytics/ultralytics/blob/main/examples/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open Ultralytics In Colab"></a>
#   <a href="https://www.kaggle.com/models/ultralytics/yolo26"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open Ultralytics In Kaggle"></a>
#   <a href="https://mybinder.org/v2/gh/ultralytics/ultralytics/HEAD?labpath=examples%2Ftutorial.ipynb"><img src="https://mybinder.org/badge_logo.svg" alt="Open Ultralytics In Binder"></a>
# </div>
#
# This **Ultralytics Colab Notebook** is the easiest way to get started with [YOLO models](https://www.ultralytics.com/yolo)—no installation needed. Built by [Ultralytics](https://www.ultralytics.com/), the creators of YOLO, this notebook walks you through running **state-of-the-art** models directly in your browser.
#
# Ultralytics models are constantly updated for performance and flexibility. They're **fast**, **accurate**, and **easy to use**, and they excel at [object detection](https://docs.ultralytics.com/tasks/detect/), [tracking](https://docs.ultralytics.com/modes/track/), [instance segmentation](https://docs.ultralytics.com/tasks/segment/), [semantic segmentation](https://docs.ultralytics.com/tasks/semantic/), [image classification](https://docs.ultralytics.com/tasks/classify/), and [pose estimation](https://docs.ultralytics.com/tasks/pose/).
#
# Find detailed documentation in the [Ultralytics Docs](https://docs.ultralytics.com/). Get support via [GitHub Issues](https://github.com/ultralytics/ultralytics/issues/new/choose). Join discussions on [Discord](https://discord.com/invite/ultralytics), [Reddit](https://www.reddit.com/r/ultralytics/), and the [Ultralytics Community Forums](https://community.ultralytics.com/)!
#
# Request an Enterprise License for commercial use at [Ultralytics Licensing](https://www.ultralytics.com/license).

# %% [markdown]
# # Setup
#
# pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/pyproject.toml) and check software and hardware.
#
# [![PyPI - Version](https://img.shields.io/pypi/v/ultralytics?logo=pypi&logoColor=white)](https://pypi.org/project/ultralytics/) [![Downloads](https://static.pepy.tech/badge/ultralytics)](https://clickpy.clickhouse.com/dashboard/ultralytics) [![PyPI - Python Version](https://img.shields.io/pypi/pyversions/ultralytics?logo=python&logoColor=gold)](https://pypi.org/project/ultralytics/)

# %%
# !uv pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.72 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 47.1/112.6 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')

# Zip dosyasını Colab'ın içine çıkartıyoruz
# !unzip -q "/content/drive/MyDrive/yolo_sancak.zip" -d "/content/"
print("Veri seti başarıyla çıkartıldı!")
# Out:
# Mounted at /content/drive
# Veri seti başarıyla çıkartıldı!

# %%
from google.colab import drive
drive.mount('/content/drive')

# !cp -r "/content/drive/MyDrive/yolo_sancak" "/content/"
print("Veri seti Drive'dan Colab'a başarıyla kopyalandı!")
# Out:
# Mounted at /content/drive
# Veri seti Drive'dan Colab'a başarıyla kopyalandı!

# %%
from ultralytics import YOLO
from google.colab import drive
drive.mount('/content/drive')

# YOLO26 Nano modelini yüklüyoruz
model = YOLO("yolo26n.pt")

# Eğitimi başlatıyoruz
results = model.train(
    data="/content/yolo_sancak/data.yaml",
    epochs=150,
    imgsz=640,
    project="/content/drive/MyDrive/Sancak_Egitim_Sonuclari",
    name="sancak_yolo26_nano_final"
)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 100.3MB/s 0.1s
# Ultralytics 8.4.72 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/yolo_sancak/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=150, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=sancak_yolo26_nano_final-2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/Sancak_Egitim_Sonuclari, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/Sancak_Egitim_Sonuclari/sancak_yolo26_nano_final-2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 24.3MB/s 0.0s
# Overriding model.yaml nc=80 with nc=5
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    243126  ultralytics.nn.modules.head.Detect           [5, 1, True, [64, 128, 256]]
# YOLO26n summary: 260 layers, 2,505,750 parameters, 2,505,750 gradients, 5.8 GFLOPs
#
# Transferred 606/708 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2896.4±1683.5 MB/s, size: 3298.3 KB)
# train: Scanning /content/yolo_sancak/labels/train... 3200 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3200/3200 59.7it/s 53.6s
# train: New cache created: /content/yolo_sancak/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3114.9±1697.0 MB/s, size: 3243.2 KB)
# val: Scanning /content/yolo_sancak/labels/val... 800 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 800/800 57.1it/s 14.0s
# val: New cache created: /content/yolo_sancak/labels/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001111, momentum=0.9) with parameter groups 114 weight(decay=0.0), 126 weight(decay=0.0005), 126 bias(decay=0.0)
# Plotting labels to /content/drive/MyDrive/Sancak_Egitim_Sonuclari/sancak_yolo26_nano_final-2/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /content/drive/MyDrive/Sancak_Egitim_Sonuclari/sancak_yolo26_nano_final-2
# Starting training for 150 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/150      2.53G     0.7296      5.603   0.005446         30        640: 100% ━━━━━━━━━━━━ 200/200 3.6it/s 55.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 3.1it/s 8.2s
#                    all        800        800      0.773      0.739       0.85      0.811
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/150      2.53G     0.7166      3.068   0.005309         33        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 42.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.6it/s 5.5s
#                    all        800        800      0.852       0.87      0.943      0.904
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/150      2.53G     0.7494      1.778   0.005635         34        640: 100% ━━━━━━━━━━━━ 200/200 5.0it/s 40.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.1it/s 4.9s
#                    all        800        800      0.845      0.903      0.971      0.868
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/150      2.53G      0.746      1.197   0.005661         34        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 42.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.0it/s 5.0s
#                    all        800        800      0.871      0.914       0.97      0.908
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/150      2.53G     0.6355     0.8955   0.004809         39        640: 100% ━━━━━━━━━━━━ 200/200 5.0it/s 40.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.1it/s 4.9s
#                    all        800        800      0.897      0.902      0.966      0.911
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/150      2.53G     0.6257     0.7519    0.00469         37        640: 100% ━━━━━━━━━━━━ 200/200 4.6it/s 43.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.4it/s 4.6s
#                    all        800        800      0.903      0.918      0.973      0.943
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/150      2.53G     0.6094     0.6648    0.00472         37        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 40.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.5it/s 5.5s
#                    all        800        800      0.903      0.906      0.967      0.926
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/150      2.53G     0.5841     0.6391   0.004398         37        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 41.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.3it/s 5.8s
#                    all        800        800        0.9      0.929      0.972      0.937
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/150      2.53G     0.5753     0.5905   0.004395         32        640: 100% ━━━━━━━━━━━━ 200/200 5.1it/s 39.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.1it/s 6.1s
#                    all        800        800      0.933      0.923      0.976      0.939
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/150      2.53G     0.5629     0.5679   0.004357         26        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 41.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.0it/s 5.0s
#                    all        800        800      0.906      0.939      0.976      0.954
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/150      2.53G     0.5548     0.5241    0.00421         29        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 42.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.3it/s 4.7s
#                    all        800        800      0.934      0.953      0.987      0.962
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/150      2.53G     0.5463     0.4668    0.00417         32        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.4it/s 4.6s
#                    all        800        800      0.943      0.964       0.99       0.95
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/150      2.53G     0.5454     0.4726   0.004146         35        640: 100% ━━━━━━━━━━━━ 200/200 4.7it/s 42.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.6it/s 4.5s
#                    all        800        800      0.949      0.973      0.989      0.968
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/150      2.53G     0.5163     0.4279   0.003907         39        640: 100% ━━━━━━━━━━━━ 200/200 5.0it/s 40.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.0it/s 5.0s
#                    all        800        800      0.953      0.977       0.99      0.973
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/150      2.53G     0.5225     0.4088   0.004038         34        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.6it/s 5.4s
#                    all        800        800      0.979      0.967      0.992      0.983
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/150      2.53G     0.4889      0.383    0.00376         32        640: 100% ━━━━━━━━━━━━ 200/200 5.0it/s 40.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.4it/s 4.6s
#                    all        800        800      0.966      0.967       0.99      0.966
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/150      2.53G     0.5009     0.4161   0.003815         26        640: 100% ━━━━━━━━━━━━ 200/200 4.7it/s 42.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.4it/s 5.7s
#                    all        800        800      0.949      0.961       0.99      0.974
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/150      2.53G     0.5062     0.3823   0.003927         36        640: 100% ━━━━━━━━━━━━ 200/200 5.0it/s 40.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.5it/s 5.6s
#                    all        800        800      0.971      0.968      0.991      0.975
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/150      2.53G     0.4933      0.361   0.003845         34        640: 100% ━━━━━━━━━━━━ 200/200 5.0it/s 39.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.5it/s 4.5s
#                    all        800        800      0.981       0.98      0.994      0.978
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/150      2.53G     0.4949      0.372   0.003732         33        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.4it/s 5.6s
#                    all        800        800      0.971      0.971      0.988      0.983
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/150      2.53G     0.4928     0.3751   0.003869         30        640: 100% ━━━━━━━━━━━━ 200/200 4.7it/s 42.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 7.4it/s 3.4s
#                    all        800        800      0.975      0.977      0.993      0.986
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/150      2.53G     0.4591     0.3385   0.003556         29        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.2it/s 4.8s
#                    all        800        800      0.982      0.987      0.994       0.99
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/150      2.53G     0.4706     0.3485   0.003607         31        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 40.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.4it/s 4.6s
#                    all        800        800       0.98      0.982      0.993      0.983
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/150      2.53G     0.4828     0.3309   0.003694         38        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 42.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.3it/s 4.8s
#                    all        800        800      0.969      0.992      0.993      0.986
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/150      2.53G     0.4682     0.3289   0.003574         33        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.6it/s 5.4s
#                    all        800        800      0.983      0.979      0.994      0.987
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/150      2.53G     0.4661     0.3169   0.003629         39        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 41.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.3it/s 4.7s
#                    all        800        800      0.977      0.988      0.994      0.989
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/150      2.53G     0.4647     0.3208   0.003544         36        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.5it/s 5.6s
#                    all        800        800      0.988      0.978      0.994      0.989
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/150      2.53G     0.4636     0.3105   0.003538         47        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 40.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.5it/s 5.5s
#                    all        800        800      0.969      0.992      0.993       0.99
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/150      2.53G     0.4649     0.3239   0.003601         33        640: 100% ━━━━━━━━━━━━ 200/200 5.0it/s 40.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.4it/s 5.7s
#                    all        800        800       0.99      0.978      0.994      0.988
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/150      2.53G     0.4481     0.3109     0.0034         28        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.5it/s 4.5s
#                    all        800        800      0.988      0.989      0.994      0.988
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/150      2.53G     0.4567     0.3029   0.003545         30        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 6.7it/s 3.7s
#                    all        800        800       0.97      0.985      0.993      0.987
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/150      2.53G     0.4539     0.3009   0.003449         29        640: 100% ━━━━━━━━━━━━ 200/200 4.6it/s 43.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.6it/s 4.5s
#                    all        800        800       0.99      0.986      0.994       0.99
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/150      2.53G     0.4548     0.3075   0.003468         25        640: 100% ━━━━━━━━━━━━ 200/200 5.0it/s 40.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.6it/s 4.4s
#                    all        800        800      0.978      0.991      0.994      0.989
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/150      2.53G     0.4551     0.3207   0.003488         29        640: 100% ━━━━━━━━━━━━ 200/200 4.7it/s 42.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.9it/s 5.1s
#                    all        800        800      0.988      0.963      0.993      0.989
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/150      2.53G     0.4627     0.3279   0.003622         36        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 40.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.3it/s 5.8s
#                    all        800        800      0.979      0.991      0.994       0.99
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/150      2.53G      0.453     0.2921   0.003538         38        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.1it/s 4.9s
#                    all        800        800      0.983      0.982      0.994      0.991
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/150      2.53G     0.4466     0.2878   0.003475         39        640: 100% ━━━━━━━━━━━━ 200/200 5.0it/s 39.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.8it/s 4.3s
#                    all        800        800      0.981      0.988      0.994      0.992
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/150      2.53G     0.4299     0.2703   0.003337         32        640: 100% ━━━━━━━━━━━━ 200/200 4.7it/s 42.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.9it/s 5.1s
#                    all        800        800      0.977      0.989      0.994       0.99
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/150      2.53G     0.4484     0.2633    0.00343         39        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.2it/s 4.8s
#                    all        800        800       0.99      0.992      0.995      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/150      2.53G     0.4408     0.2783   0.003443         26        640: 100% ━━━━━━━━━━━━ 200/200 5.0it/s 40.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.9it/s 5.1s
#                    all        800        800      0.985      0.986      0.994      0.991
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/150      2.53G     0.4395     0.2778   0.003458         30        640: 100% ━━━━━━━━━━━━ 200/200 5.0it/s 40.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.6it/s 5.4s
#                    all        800        800      0.977      0.988      0.994      0.991
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/150      2.53G     0.4328     0.2808   0.003389         30        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 42.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.2it/s 4.8s
#                    all        800        800      0.991      0.987      0.994      0.992
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/150      2.53G      0.432     0.2692   0.003346         30        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 40.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.5it/s 4.5s
#                    all        800        800      0.993      0.992      0.995      0.991
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/150      2.53G     0.4344     0.2626   0.003362         39        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.1it/s 4.9s
#                    all        800        800      0.986      0.995      0.995      0.992
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/150      2.53G     0.4329     0.2558   0.003366         36        640: 100% ━━━━━━━━━━━━ 200/200 4.7it/s 42.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.0it/s 5.0s
#                    all        800        800      0.994      0.986      0.995      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/150      2.53G     0.4287     0.2677   0.003269         35        640: 100% ━━━━━━━━━━━━ 200/200 5.1it/s 38.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.8it/s 5.2s
#                    all        800        800      0.998      0.991      0.995      0.991
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/150      2.53G     0.4257     0.2554   0.003287         36        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.8it/s 5.2s
#                    all        800        800      0.988      0.996      0.995      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/150      2.53G     0.4078     0.2387   0.003139         37        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 41.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.8it/s 4.3s
#                    all        800        800      0.983      0.985      0.994      0.992
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/150      2.53G     0.4226     0.2579   0.003272         34        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 6.9it/s 3.6s
#                    all        800        800      0.992      0.986      0.994      0.992
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/150      2.53G     0.4204     0.2488    0.00323         34        640: 100% ━━━━━━━━━━━━ 200/200 4.7it/s 42.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.5it/s 5.5s
#                    all        800        800      0.981      0.997      0.995      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/150      2.53G     0.4085     0.2554   0.003111         29        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 41.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.9it/s 5.1s
#                    all        800        800      0.985      0.997      0.994      0.992
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/150      2.53G     0.4149     0.2446   0.003151         38        640: 100% ━━━━━━━━━━━━ 200/200 4.7it/s 42.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.9it/s 5.1s
#                    all        800        800      0.982      0.995      0.994      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/150      2.53G     0.4101     0.2476    0.00317         27        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 40.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.8it/s 5.2s
#                    all        800        800      0.986      0.993      0.994      0.992
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/150      2.53G     0.4082     0.2397   0.003212         30        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 41.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.9it/s 5.1s
#                    all        800        800      0.987      0.994      0.994      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/150      2.53G      0.396     0.2456   0.003058         35        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 42.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.4it/s 4.6s
#                    all        800        800       0.99       0.99      0.994      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/150      2.53G     0.4129     0.2427   0.003185         25        640: 100% ━━━━━━━━━━━━ 200/200 5.0it/s 40.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.7it/s 4.4s
#                    all        800        800      0.992      0.995      0.995      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/150      2.53G     0.4111     0.2305   0.003187         30        640: 100% ━━━━━━━━━━━━ 200/200 4.7it/s 42.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 6.3it/s 4.0s
#                    all        800        800      0.991      0.998      0.995      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/150      2.53G     0.3918     0.2227   0.003037         32        640: 100% ━━━━━━━━━━━━ 200/200 4.7it/s 42.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.0it/s 5.0s
#                    all        800        800      0.994      0.983      0.994      0.992
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/150      2.53G     0.3971     0.2239   0.003124         43        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.8it/s 4.3s
#                    all        800        800      0.993      0.994      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/150      2.53G     0.3944      0.232   0.003017         32        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.5it/s 4.5s
#                    all        800        800      0.989      0.994      0.994      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/150      2.53G     0.4004     0.2229   0.003047         39        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.2it/s 4.8s
#                    all        800        800      0.994      0.988      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/150      2.53G     0.3974     0.2211   0.003026         35        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.5it/s 4.6s
#                    all        800        800      0.983      0.994      0.994      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/150      2.53G     0.3931     0.2281   0.003032         33        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.7it/s 4.4s
#                    all        800        800      0.991      0.993      0.994      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/150      2.53G     0.3981     0.2264   0.003013         32        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.2it/s 6.0s
#                    all        800        800      0.991      0.999      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/150      2.53G     0.3896      0.213   0.003035         34        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 6.1it/s 4.1s
#                    all        800        800      0.993      0.987      0.994      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/150      2.53G      0.386     0.2253   0.002955         42        640: 100% ━━━━━━━━━━━━ 200/200 4.7it/s 42.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.2it/s 4.8s
#                    all        800        800      0.992      0.994      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/150      2.53G     0.3768     0.2249   0.002897         38        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 41.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.8it/s 5.2s
#                    all        800        800      0.995      0.988      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/150      2.53G     0.3987     0.2241    0.00312         34        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 40.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.6it/s 4.5s
#                    all        800        800      0.995       0.99      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/150      2.53G     0.3887     0.2255   0.003026         38        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 42.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.7it/s 4.4s
#                    all        800        800      0.992      0.992      0.994      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/150      2.53G     0.3833     0.2167   0.002909         35        640: 100% ━━━━━━━━━━━━ 200/200 4.6it/s 43.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.9it/s 4.2s
#                    all        800        800      0.993      0.993      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/150      2.53G     0.3759     0.2131   0.002959         40        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.5it/s 4.6s
#                    all        800        800      0.996      0.994      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/150      2.53G     0.3837     0.2073   0.002985         41        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.4it/s 4.6s
#                    all        800        800      0.992      0.998      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/150      2.53G     0.3759     0.2157   0.002887         44        640: 100% ━━━━━━━━━━━━ 200/200 4.6it/s 43.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.9it/s 5.1s
#                    all        800        800      0.992      0.996      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/150      2.53G     0.3696     0.1998   0.002845         27        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.5it/s 4.5s
#                    all        800        800      0.994       0.99      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/150      2.53G     0.3669     0.2037   0.002835         40        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.6it/s 5.5s
#                    all        800        800      0.993      0.993      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/150      2.53G      0.374      0.215   0.002904         34        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 41.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.0it/s 5.0s
#                    all        800        800      0.996       0.99      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/150      2.53G     0.3693     0.2044   0.002848         28        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.8it/s 4.3s
#                    all        800        800      0.992      0.996      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/150      2.53G     0.3726     0.2055   0.002852         39        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.8it/s 5.2s
#                    all        800        800      0.995       0.99      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/150      2.53G     0.3769     0.2023   0.002908         36        640: 100% ━━━━━━━━━━━━ 200/200 4.7it/s 42.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.9it/s 4.2s
#                    all        800        800      0.995      0.992      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/150      2.53G     0.3795     0.2151   0.002959         32        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 41.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.0it/s 5.0s
#                    all        800        800      0.994      0.999      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/150      2.53G      0.369     0.1953   0.002796         36        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 42.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.4it/s 4.6s
#                    all        800        800      0.993      0.994      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/150      2.53G     0.3669     0.1977    0.00281         36        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 40.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.6it/s 5.4s
#                    all        800        800      0.993      0.994      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/150      2.53G     0.3681      0.196   0.002826         33        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.1it/s 4.9s
#                    all        800        800      0.995      0.996      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/150      2.53G     0.3585     0.2002   0.002733         27        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.8it/s 5.2s
#                    all        800        800      0.996      0.994      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/150      2.53G     0.3549     0.1819   0.002746         37        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.7it/s 4.4s
#                    all        800        800      0.993      0.999      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/150      2.53G     0.3696     0.2045   0.002832         33        640: 100% ━━━━━━━━━━━━ 200/200 4.7it/s 42.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 6.1it/s 4.1s
#                    all        800        800      0.992      0.996      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/150      2.53G     0.3588     0.2017   0.002858         39        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 41.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.6it/s 5.4s
#                    all        800        800      0.996      0.993      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/150      2.53G     0.3511      0.181   0.002734         35        640: 100% ━━━━━━━━━━━━ 200/200 5.0it/s 40.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.2it/s 4.8s
#                    all        800        800      0.995      0.998      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/150      2.53G     0.3545     0.1835   0.002703         34        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 41.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.7it/s 5.3s
#                    all        800        800      0.996      0.996      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/150      2.53G     0.3578      0.182    0.00274         32        640: 100% ━━━━━━━━━━━━ 200/200 4.7it/s 42.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.9it/s 4.2s
#                    all        800        800      0.994      0.994      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/150      2.53G     0.3428     0.1781   0.002649         34        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 42.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 6.2it/s 4.0s
#                    all        800        800      0.995      0.997      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/150      2.53G     0.3487     0.1798   0.002693         38        640: 100% ━━━━━━━━━━━━ 200/200 4.7it/s 42.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.5it/s 5.5s
#                    all        800        800      0.996      0.995      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/150      2.53G     0.3607     0.1815   0.002755         24        640: 100% ━━━━━━━━━━━━ 200/200 5.0it/s 39.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.4it/s 5.7s
#                    all        800        800      0.991      0.995      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/150      2.53G     0.3442      0.182   0.002632         26        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 41.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.6it/s 4.4s
#                    all        800        800      0.997      0.998      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/150      2.53G     0.3563     0.1832   0.002715         34        640: 100% ━━━━━━━━━━━━ 200/200 4.6it/s 43.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.3it/s 4.7s
#                    all        800        800      0.998      0.992      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/150      2.53G     0.3552     0.1937   0.002763         29        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 7.2it/s 3.5s
#                    all        800        800      0.997      0.993      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/150      2.53G     0.3498     0.1835   0.002659         30        640: 100% ━━━━━━━━━━━━ 200/200 4.7it/s 42.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.3it/s 4.7s
#                    all        800        800      0.998      0.996      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/150      2.53G     0.3426     0.1765   0.002672         41        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.4it/s 4.6s
#                    all        800        800      0.996      0.997      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/150      2.53G     0.3458     0.1772   0.002639         29        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.9it/s 4.2s
#                    all        800        800          1      0.996      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/150      2.53G     0.3451     0.1764   0.002633         35        640: 100% ━━━━━━━━━━━━ 200/200 4.6it/s 43.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.5it/s 4.6s
# ...
#     116/150      2.53G     0.3046     0.1539   0.002276         31        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 40.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.5it/s 4.6s
#                    all        800        800      0.994          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     117/150      2.53G     0.3173     0.1594   0.002425         34        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 40.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.9it/s 5.1s
#                    all        800        800      0.994      0.999      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     118/150      2.53G     0.3244     0.1623    0.00252         32        640: 100% ━━━━━━━━━━━━ 200/200 4.7it/s 42.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.0it/s 5.0s
#                    all        800        800      0.997      0.996      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     119/150      2.53G     0.3148     0.1529   0.002364         42        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 40.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.9it/s 5.1s
#                    all        800        800      0.997      0.996      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     120/150      2.53G     0.3244     0.1661   0.002481         31        640: 100% ━━━━━━━━━━━━ 200/200 4.6it/s 43.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 6.7it/s 3.7s
#                    all        800        800      0.996      0.996      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     121/150      2.53G      0.321     0.1539    0.00245         28        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 42.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 6.7it/s 3.7s
#                    all        800        800      0.998      0.996      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     122/150      2.53G     0.3071     0.1525    0.00236         36        640: 100% ━━━━━━━━━━━━ 200/200 4.7it/s 42.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.1it/s 4.9s
#                    all        800        800      0.999      0.995      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     123/150      2.53G     0.3075     0.1541   0.002339         40        640: 100% ━━━━━━━━━━━━ 200/200 4.7it/s 42.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.7it/s 4.4s
#                    all        800        800      0.997       0.99      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     124/150      2.53G     0.3149      0.154   0.002387         35        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.5it/s 4.6s
#                    all        800        800      0.995      0.996      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     125/150      2.53G     0.3105     0.1502   0.002361         33        640: 100% ━━━━━━━━━━━━ 200/200 4.7it/s 42.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 6.0it/s 4.2s
#                    all        800        800      0.997      0.999      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     126/150      2.53G     0.3073     0.1486   0.002315         37        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 41.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.8it/s 5.2s
#                    all        800        800      0.995      0.997      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     127/150      2.53G     0.3208     0.1539   0.002401         34        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 41.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.7it/s 5.3s
#                    all        800        800      0.997      0.996      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     128/150      2.53G     0.3118     0.1509   0.002356         34        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 40.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.5it/s 5.5s
#                    all        800        800      0.998      0.999      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     129/150      2.53G     0.2994     0.1504    0.00224         40        640: 100% ━━━━━━━━━━━━ 200/200 5.0it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.5it/s 5.5s
#                    all        800        800      0.996      0.993      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     130/150      2.53G     0.3031      0.146    0.00228         29        640: 100% ━━━━━━━━━━━━ 200/200 4.7it/s 42.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.2it/s 4.8s
#                    all        800        800      0.992      0.997      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     131/150      2.53G     0.3095     0.1548   0.002333         29        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.4it/s 4.7s
#                    all        800        800      0.997      0.996      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     132/150      2.53G     0.3083     0.1535   0.002357         32        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 6.5it/s 3.9s
#                    all        800        800      0.996      0.996      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     133/150      2.53G     0.2972     0.1497   0.002194         25        640: 100% ━━━━━━━━━━━━ 200/200 4.7it/s 42.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 6.3it/s 4.0s
#                    all        800        800      0.995      0.996      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     134/150      2.53G     0.2913     0.1414   0.002202         29        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.9it/s 4.2s
#                    all        800        800      0.993      0.998      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     135/150      2.53G     0.2986     0.1512   0.002209         32        640: 100% ━━━━━━━━━━━━ 200/200 4.6it/s 43.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 6.4it/s 3.9s
#                    all        800        800      0.997      0.993      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     136/150      2.53G     0.2888     0.1459   0.002117         29        640: 100% ━━━━━━━━━━━━ 200/200 4.7it/s 42.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.6it/s 4.5s
#                    all        800        800      0.995      0.997      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     137/150      2.53G     0.2911      0.143   0.002176         27        640: 100% ━━━━━━━━━━━━ 200/200 4.7it/s 42.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.0it/s 5.0s
#                    all        800        800      0.996          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     138/150      2.53G     0.2981     0.1482   0.002249         36        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 40.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.4it/s 5.7s
#                    all        800        800      0.995      0.999      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     139/150      2.53G     0.2994     0.1422   0.002218         28        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.9it/s 5.1s
#                    all        800        800      0.997      0.998      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     140/150      2.53G     0.2934     0.1463   0.002239         29        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 40.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.5it/s 5.6s
#                    all        800        800      0.999      0.997      0.995      0.995
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     141/150      2.53G     0.1369    0.06596   0.001115         16        640: 100% ━━━━━━━━━━━━ 200/200 4.6it/s 43.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.1it/s 4.9s
#                    all        800        800      0.996      0.999      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     142/150      2.53G     0.1319    0.05786   0.001096         16        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 40.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.3it/s 4.8s
#                    all        800        800      0.998      0.997      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     143/150      2.53G     0.1262    0.05498   0.001006         16        640: 100% ━━━━━━━━━━━━ 200/200 4.8it/s 41.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.4it/s 4.7s
#                    all        800        800      0.996      0.997      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     144/150      2.53G     0.1297    0.05325   0.001048         16        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 41.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.4it/s 4.6s
#                    all        800        800      0.999      0.997      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     145/150      2.53G     0.1289    0.05439   0.001025         16        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 40.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.7it/s 4.4s
#                    all        800        800      0.997      0.996      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     146/150      2.53G     0.1267    0.05328   0.001016         16        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 41.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.2it/s 4.8s
#                    all        800        800      0.999      0.995      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     147/150      2.53G     0.1228    0.05461  0.0009825         16        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 40.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.5it/s 4.6s
#                    all        800        800      0.999      0.995      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     148/150      2.53G      0.125    0.05299  0.0009754         16        640: 100% ━━━━━━━━━━━━ 200/200 4.7it/s 42.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.1it/s 4.9s
#                    all        800        800      0.998      0.997      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     149/150      2.53G     0.1231    0.05407  0.0009679         16        640: 100% ━━━━━━━━━━━━ 200/200 4.9it/s 41.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 6.2it/s 4.1s
#                    all        800        800      0.998      0.998      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     150/150      2.53G     0.1211    0.05246  0.0009591         16        640: 100% ━━━━━━━━━━━━ 200/200 5.0it/s 40.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 4.8it/s 5.2s
#                    all        800        800      0.998      0.998      0.995      0.995
#
# 150 epochs completed in 1.991 hours.
# Optimizer stripped from /content/drive/MyDrive/Sancak_Egitim_Sonuclari/sancak_yolo26_nano_final-2/weights/last.pt, 5.4MB
# Optimizer stripped from /content/drive/MyDrive/Sancak_Egitim_Sonuclari/sancak_yolo26_nano_final-2/weights/best.pt, 5.4MB
#
# Validating /content/drive/MyDrive/Sancak_Egitim_Sonuclari/sancak_yolo26_nano_final-2/weights/best.pt...
# Ultralytics 8.4.72 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA A100-SXM4-40GB, 40441MiB)
# YOLO26n summary (fused): 122 layers, 2,375,811 parameters, 0 gradients, 5.2 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 7.1it/s 3.5s
#                    all        800        800      0.999      0.997      0.995      0.995
#                  Drone        195        195      0.998          1      0.995      0.995
#             Helicopter        200        200      0.998      0.995      0.995      0.995
#                    Jet        197        197          1      0.998      0.995      0.995
#                 Rocket        208        208      0.999      0.995      0.995      0.995
# Speed: 0.1ms preprocess, 0.9ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to /content/drive/MyDrive/Sancak_Egitim_Sonuclari/sancak_yolo26_nano_final-2

# %%
# !yolo export model="/content/drive/MyDrive/Sancak_Egitim_Sonuclari/sancak_yolo26_nano_final/weights/best.pt" format=onnx imgsz=640 opset=17 simplify=True dynamic=False end2end=False
# Out:
# Ultralytics 8.4.72 🚀 Python-3.12.13 torch-2.11.0+cu128 CPU (Intel Xeon CPU @ 2.20GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLO26n summary (fused): 146 layers, 2,496,254 parameters, 0 gradients, 5.2 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/Sancak_Egitim_Sonuclari/sancak_yolo26_nano_final/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 9, 8400) (19.8 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0,<2.0.0', 'onnxruntime', 'onnxslim>=0.1.82'] not found, attempting AutoUpdate...
# Using Python 3.12.13 environment at: /usr
# Resolved 12 packages in 253ms
# Prepared 4 packages in 1.71s
# Installed 4 packages in 253ms
#  + colorama==0.4.6
#  + onnx==1.22.0
#  + onnxruntime==1.27.0
#  + onnxslim==0.1.94
#
# requirements: AutoUpdate success ✅ 2.5s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.22.0 opset 17...
# ONNX: slimming with onnxslim 0.1.94...
# ONNX: export success ✅ 4.4s, saved as '/content/drive/MyDrive/Sancak_Egitim_Sonuclari/sancak_yolo26_nano_final/weights/best.onnx' (9.3 MB)
#
# Export complete (4.8s)
# Results saved to /content/drive/MyDrive/Sancak_Egitim_Sonuclari/sancak_yolo26_nano_final/weights/best.onnx
# Predict:         yolo predict task=detect model=/content/drive/MyDrive/Sancak_Egitim_Sonuclari/sancak_yolo26_nano_final/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=/content/drive/MyDrive/Sancak_Egitim_Sonuclari/sancak_yolo26_nano_final/weights/best.onnx imgsz=640 data=/content/yolo_sancak/data.yaml
# Visualize:       https://netron.app
# 💡 Learn more at https://docs.ultralytics.com/modes/export

# %% [markdown]
# # 1. Predict
#
# YOLO26 may be used directly in the Command Line Interface (CLI) with a `yolo` command for a variety of tasks and modes and accepts additional arguments, i.e. `imgsz=640`. See a full list of available `yolo` [arguments](https://docs.ultralytics.com/usage/cfg/) and other details in the [YOLO26 Predict Docs](https://docs.ultralytics.com/modes/predict/).

# %%
# Run inference on an image with YOLO26n
# !yolo predict model=yolo26n.pt source='https://ultralytics.com/images/zidane.jpg'
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 293.5MB/s 0.0s
# Ultralytics 8.4.4 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO26n summary (fused): 122 layers, 2,408,932 parameters, 0 gradients, 5.4 GFLOPs
#
# Downloading https://ultralytics.com/images/zidane.jpg to 'zidane.jpg': 100% ━━━━━━━━━━━━ 49.2KB 42.2MB/s 0.0s
# image 1/1 /content/zidane.jpg: 384x640 2 persons, 1 tie, 56.0ms
# Speed: 11.6ms preprocess, 56.0ms inference, 36.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/212889447-69e5bdf1-5800-4e29-835e-2ed2336dede2.jpg" width="600">

# %% [markdown]
# # 2. Val
# Validate a model's accuracy on the [COCO](https://docs.ultralytics.com/datasets/detect/coco/) dataset's `val` or `test` splits. The latest YOLO26 [models](https://github.com/ultralytics/ultralytics#models) are downloaded automatically the first time they are used. See [YOLO26 Val Docs](https://docs.ultralytics.com/modes/val/) for more information.

# %%
# Download COCO val
from ultralytics.utils.downloads import download

download('https://ultralytics.com/assets/coco2017val.zip', unzip=True, dir='datasets') # download (780MB - 5000 images)

# %%
# Validate YOLO26n on COCO8 val
# !yolo val model=yolo26n.pt data=coco8.yaml
# Out:
# Ultralytics 8.4.4 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO26n summary (fused): 122 layers, 2,408,932 parameters, 0 gradients, 5.4 GFLOPs
#
# WARNING ⚠️ Dataset 'coco8.yaml' images not found, missing path '/content/datasets/coco8/images/val'
# Downloading https://ultralytics.com/assets/coco8.zip to '/content/datasets/coco8.zip': 100% ━━━━━━━━━━━━ 432.8KB 36.5MB/s 0.0s
# Unzipping /content/datasets/coco8.zip to /content/datasets/coco8...: 100% ━━━━━━━━━━━━ 25/25 5.1Kfiles/s 0.0s
# Dataset download success ✅ (0.7s), saved to /content/datasets
#
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 106.1MB/s 0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1236.6±358.3 MB/s, size: 54.0 KB)
# val: Scanning /content/datasets/coco8/labels/val... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 103.0it/s 0.0s
# val: New cache created: /content/datasets/coco8/labels/val.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.1s/it 1.1s
#                    all          4         17      0.849      0.654      0.907      0.667
#                 person          3         10          1      0.427      0.766      0.378
#                    dog          1          1      0.718          1      0.995      0.597
#                  horse          1          2        0.8          1      0.995      0.798
#               elephant          1          2      0.854        0.5      0.695      0.438
#               umbrella          1          1      0.724          1      0.995      0.895
#           potted plant          1          1          1          0      0.995      0.895
# Speed: 1.0ms preprocess, 16.3ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /content/runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# # 3. Train
#
# <p align=""><a href="https://ultralytics.com/hub"><img width="1000" src="https://github.com/ultralytics/assets/raw/main/yolov8/banner-integrations.png"/></a></p>
#
# Train YOLO26 on [Detect](https://docs.ultralytics.com/tasks/detect/), [Segment](https://docs.ultralytics.com/tasks/segment/), [Semantic](https://docs.ultralytics.com/tasks/semantic/), [Classify](https://docs.ultralytics.com/tasks/classify/) and [Pose](https://docs.ultralytics.com/tasks/pose/) datasets. See [YOLO26 Train Docs](https://docs.ultralytics.com/modes/train/) for more information.

# %%
#@title Select YOLO26 🚀 logger {run: 'auto'}
logger = 'TensorBoard' #@param ['TensorBoard', 'Weights & Biases']

if logger == 'TensorBoard':
  # !yolo settings tensorboard=True
  # %load_ext tensorboard
  # %tensorboard --logdir .
elif logger == 'Weights & Biases':
  # !yolo settings wandb=True

# %%
# Train YOLO26n on COCO8 for 3 epochs
# !yolo train model=yolo26n.pt data=coco8.yaml epochs=3 imgsz=640
# Out:
# Ultralytics 8.4.4 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=coco8.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=3, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    309656  ultralytics.nn.modules.head.Detect           [80, 1, True, [64, 128, 256]]
# YOLO26n summary: 260 layers, 2,572,280 parameters, 2,572,280 gradients, 6.1 GFLOPs
#
# Transferred 708/708 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1628.3±611.0 MB/s, size: 50.0 KB)
# train: Scanning /content/datasets/coco8/labels/train... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 1.8Kit/s 0.0s
# train: New cache created: /content/datasets/coco8/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.1 ms, read: 439.1±56.8 MB/s, size: 54.0 KB)
# val: Scanning /content/datasets/coco8/labels/val.cache... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 151.1Kit/s 0.0s
# Plotting labels to /content/runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.000119, momentum=0.9) with parameter groups 0 weight(decay=0.0), 0 weight(decay=0.0005), 24 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/train
# Starting training for 3 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/3      0.75G     0.8467       1.76    0.01101         29        640: 100% ━━━━━━━━━━━━ 1/1 11.5s/it 11.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.2s/it 3.2s
#                    all          4         17        0.9      0.653      0.901      0.668
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/3     0.779G      1.332      2.559    0.01988         46        640: 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.0it/s 0.2s
#                    all          4         17      0.895      0.655      0.902      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/3     0.805G     0.9497       2.61    0.01205         20        640: 100% ━━━━━━━━━━━━ 1/1 3.7it/s 0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 7.4it/s 0.1s
#                    all          4         17      0.874       0.66      0.904      0.667
#
# 3 epochs completed in 0.005 hours.
# Optimizer stripped from /content/runs/detect/train/weights/last.pt, 5.5MB
# Optimizer stripped from /content/runs/detect/train/weights/best.pt, 5.5MB
#
# Validating /content/runs/detect/train/weights/best.pt...
# Ultralytics 8.4.4 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO26n summary (fused): 122 layers, 2,408,932 parameters, 0 gradients, 5.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 25.9it/s 0.0s
#                    all          4         17        0.9      0.653      0.901      0.668
#                 person          3         10          1       0.42      0.766      0.385
#                    dog          1          1      0.745          1      0.995      0.597
#                  horse          1          2      0.818          1      0.995      0.798
#               elephant          1          2       0.84        0.5      0.662      0.434
#               umbrella          1          1          1          1      0.995      0.895
#           potted plant          1          1          1          0      0.995      0.895
# Speed: 0.3ms preprocess, 4.8ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to /content/runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# # 4. Export
#
# Export a YOLO model to any supported format below with the `format` argument, i.e. `format=onnx`. See [Export Docs](https://docs.ultralytics.com/modes/export/) for more information.
#
# - 💡 ProTip: Export to [ONNX](https://docs.ultralytics.com/integrations/onnx/) or [OpenVINO](https://docs.ultralytics.com/integrations/openvino/) for up to 3x CPU speedup.
# - 💡 ProTip: Export to [TensorRT](https://docs.ultralytics.com/integrations/tensorrt/) for up to 5x GPU speedup.
#
# | Format | `format` Argument | Model | Metadata | Arguments |
# |--------|-----------------|-------|----------|------------|
# | [PyTorch](https://pytorch.org/) | - | `yolo26n.pt` | ✅ | - |
# | [TorchScript](https://docs.ultralytics.com/integrations/torchscript) | `torchscript` | `yolo26n.torchscript` | ✅ | `imgsz`, `batch`, `dynamic`, `optimize`, `half`, `nms`, `device` |
# | [ONNX](https://docs.ultralytics.com/integrations/onnx) | `onnx` | `yolo26n.onnx` | ✅ | `imgsz`, `batch`, `data`, `fraction`, `dynamic`, `half`, `int8`, `opset`, `simplify`, `nms`, `device` |
# | [OpenVINO](https://docs.ultralytics.com/integrations/openvino) | `openvino` | `yolo26n_openvino_model/` | ✅ | `imgsz`, `batch`, `data`, `fraction`, `dynamic`, `half`, `int8`, `nms`, `device` |
# | [TensorRT](https://docs.ultralytics.com/integrations/tensorrt) | `engine` | `yolo26n.engine` | ✅ | `imgsz`, `batch`, `data`, `fraction`, `dynamic`, `half`, `int8`, `simplify`, `nms`, `device`, `workspace` |
# | [CoreML](https://docs.ultralytics.com/integrations/coreml) | `coreml` | `yolo26n.mlpackage` | ✅ | `imgsz`, `batch`, `half`, `int8`, `nms`, `device` |
# | [TF SavedModel](https://docs.ultralytics.com/integrations/tf-savedmodel) | `saved_model` | `yolo26n_saved_model/` | ✅ | `imgsz`, `batch`, `data`, `fraction`, `int8`, `keras`, `nms`, `device` |
# | [TF GraphDef](https://docs.ultralytics.com/integrations/tf-graphdef) | `pb` | `yolo26n.pb` | ❌ | `imgsz`, `batch`, `device` |
# | [TF Lite](https://docs.ultralytics.com/integrations/tflite) | `tflite` | `yolo26n.tflite` | ✅ | `imgsz`, `batch`, `data`, `fraction`, `half`, `int8`, `nms`, `device` |
# | [TF Edge TPU](https://docs.ultralytics.com/integrations/edge-tpu) | `edgetpu` | `yolo26n_edgetpu.tflite` | ✅ | `imgsz`, `int8`, `data`, `fraction`, `device` |
# | [TF.js](https://docs.ultralytics.com/integrations/tfjs) | `tfjs` | `yolo26n_web_model/` | ✅ | `imgsz`, `batch`, `data`, `fraction`, `half`, `int8`, `nms`, `device` |
# | [PaddlePaddle](https://docs.ultralytics.com/integrations/paddlepaddle) | `paddle` | `yolo26n_paddle_model/` | ✅ | `imgsz`, `batch`, `device` |
# | [MNN](https://docs.ultralytics.com/integrations/mnn) | `mnn` | `yolo26n.mnn` | ✅ | `imgsz`, `batch`, `half`, `int8`, `device` |
# | [NCNN](https://docs.ultralytics.com/integrations/ncnn) | `ncnn` | `yolo26n_ncnn_model/` | ✅ | `imgsz`, `batch`, `half`, `device` |
# | [IMX500](https://docs.ultralytics.com/integrations/sony-imx500) | `imx` | `yolo26n_imx_model/` | ✅ | `imgsz`, `int8`, `data`, `fraction`, `device` |
# | [RKNN](https://docs.ultralytics.com/integrations/rockchip-rknn) | `rknn` | `yolo26n_rknn_model/` | ✅ | `imgsz`, `batch`, `name`, `int8`, `data`, `fraction`, `device` |
# | [ExecuTorch](https://docs.ultralytics.com/integrations/executorch) | `executorch` | `yolo26n_executorch_model/` | ✅ | `imgsz`, `device` |
# | [Axelera AI](https://docs.ultralytics.com/integrations/axelera) | `axelera` | `yolo26n_axelera_model/` | ✅ | `imgsz`, `int8`, `data`, `fraction`, `device` |
# | [DEEPX](https://docs.ultralytics.com/integrations/deepx) | `deepx` | `yolo26n_deepx_model/` | ✅ | `imgsz`, `int8`, `data`, `optimize`, `device` |
# | [Qualcomm QNN](https://docs.ultralytics.com/integrations/qnn) | `qnn` | `yolo26n_qnn.onnx` | ✅ | `imgsz`, `batch`, `name`, `int8`, `data`, `fraction`, `device` |

# %%
# !yolo export model=yolo26n.pt format=torchscript
# Out:
# Ultralytics 8.4.4 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.00GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLO26n summary (fused): 122 layers, 2,408,932 parameters, 0 gradients, 5.4 GFLOPs
#
# PyTorch: starting from 'yolo26n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 300, 6) (5.3 MB)
#
# TorchScript: starting export with torch 2.9.0+cu126...
# TorchScript: export success ✅ 2.4s, saved as 'yolo26n.torchscript' (9.8 MB)
#
# Export complete (2.9s)
# Results saved to /content
# Predict:         yolo predict task=detect model=yolo26n.torchscript imgsz=640
# Validate:        yolo val task=detect model=yolo26n.torchscript imgsz=640 data=/home/lq/codes/ultralytics/ultralytics/cfg/datasets/coco.yaml
# Visualize:       https://netron.app
# 💡 Learn more at https://docs.ultralytics.com/modes/export

# %% [markdown]
# # 5. Python Usage
#
# YOLO26 was reimagined using Python-first principles for the most seamless Python YOLO experience yet. YOLO26 models can be loaded from a trained checkpoint or created from scratch. Then methods are used to train, val, predict, and export the model. See detailed Python usage examples in the [YOLO26 Python Docs](https://docs.ultralytics.com/usage/python/).

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolo26n.yaml')  # build a new model from scratch
model = YOLO('yolo26n.pt')  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data='coco8.yaml', epochs=3)  # train the model
results = model.val()  # evaluate model performance on the validation set
results = model('https://ultralytics.com/images/bus.jpg')  # predict on an image
results = model.export(format='onnx')  # export the model to ONNX format

# %% [markdown]
# # 6. Tasks
#
# YOLO26 can train, val, predict and export models for the most common tasks in vision AI: [Detect](https://docs.ultralytics.com/tasks/detect/), [Segment](https://docs.ultralytics.com/tasks/segment/), [Semantic](https://docs.ultralytics.com/tasks/semantic/), [Classify](https://docs.ultralytics.com/tasks/classify/) and [Pose](https://docs.ultralytics.com/tasks/pose/). See [YOLO26 Tasks Docs](https://docs.ultralytics.com/tasks/) for more information.
#
# <br><img width="1024" src="https://raw.githubusercontent.com/ultralytics/assets/main/im/banner-tasks.png">

# %% [markdown]
# ## 1. Detection
#
# YOLO26 _detection_ models have no suffix and are the default YOLO26 models, i.e. `yolo26n.pt` and are pretrained on COCO. See [Detection Docs](https://docs.ultralytics.com/tasks/detect/) for full details.

# %%
# Load YOLO26n, train it on COCO8 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo26n.pt')  # load a pretrained YOLO detection model
model.train(data='coco8.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# ## 2. Segmentation
#
# YOLO26 _segmentation_ models use the `-seg` suffix, i.e. `yolo26n-seg.pt` and are pretrained on COCO. See [Segmentation Docs](https://docs.ultralytics.com/tasks/segment/) for full details.

# %%
# Load YOLO26n-seg, train it on COCO8-seg for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo26n-seg.pt')  # load a pretrained YOLO segmentation model
model.train(data='coco8-seg.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# ## 3. Classification
#
# YOLO26 _classification_ models use the `-cls` suffix, i.e. `yolo26n-cls.pt` and are pretrained on ImageNet. See [Classification Docs](https://docs.ultralytics.com/tasks/classify/) for full details.

# %%
# Load YOLO26n-cls, train it on mnist160 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo26n-cls.pt')  # load a pretrained YOLO classification model
model.train(data='mnist160', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# ## 4. Pose
#
# YOLO26 _pose_ models use the `-pose` suffix, i.e. `yolo26n-pose.pt` and are pretrained on COCO Keypoints. See [Pose Docs](https://docs.ultralytics.com/tasks/pose/) for full details.

# %%
# Load YOLO26n-pose, train it on COCO8-pose for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo26n-pose.pt')  # load a pretrained YOLO pose model
model.train(data='coco8-pose.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# ## 5. Oriented Bounding Boxes (OBB)
#
# YOLO26 _OBB_ models use the `-obb` suffix, i.e. `yolo26n-obb.pt` and are pretrained on the DOTA dataset. See [OBB Docs](https://docs.ultralytics.com/tasks/obb/) for full details.

# %%
# Load YOLO26n-obb, train it on DOTA8 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo26n-obb.pt')  # load a pretrained YOLO OBB model
model.train(data='dota8.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/boats.jpg')  # predict on an image

# %% [markdown]
# # Appendix
#
# Additional content below.

# %%
# Pip install from source
# !uv pip install git+https://github.com/ultralytics/ultralytics@main

# %%
# Git clone and run tests on 'main' branch
# !git clone https://github.com/ultralytics/ultralytics -b main
# !uv pip install -qe ultralytics

# %%
# Run tests (Git clone only)
# !pytest ultralytics/tests

# %%
# Validate multiple models
for x in 'nsmlx':
  # !yolo val model=yolo26{x}.pt data=coco.yaml
